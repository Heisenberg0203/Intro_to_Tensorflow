# %%
import tensorflow as tf

# %% [markdown]
# ###  model1 with sgd as optimizer and mean squared error as loss function

# %%
mnist = tf.keras.datasets.fashion_mnist
(training_images, training_labels) ,  (test_images, test_labels) = mnist.load_data()

training_images = training_images/255.0
test_images = test_images/255.0

model = tf.keras.Sequential([tf.keras.layers.Flatten(),
                           tf.keras.layers.Dense(256,activation=tf.nn.relu),
                           tf.keras.layers.Dense(1024,activation=tf.nn.relu),
                           tf.keras.layers.Dense(10,activation=tf.nn.softmax)])

model.compile(optimizer = 'sgd',
              loss = 'mean_squared_error',metrics=['accuracy'])

model.fit(training_images, training_labels, epochs=30)

model.evaluate(test_images, test_labels,verbose=0)
# Out:
# Train on 60000 samples
# Epoch 1/30
# 60000/60000 [==============================] - 9s 149us/sample - loss: 27.6101 - accuracy: 0.0694
# Epoch 2/30
# 60000/60000 [==============================] - 8s 129us/sample - loss: 27.6101 - accuracy: 0.1024
# Epoch 3/30
# 60000/60000 [==============================] - 10s 161us/sample - loss: 27.6101 - accuracy: 0.1044
# Epoch 4/30
# 60000/60000 [==============================] - 8s 127us/sample - loss: 27.6101 - accuracy: 0.1046
# Epoch 5/30
# 60000/60000 [==============================] - 5s 81us/sample - loss: 27.6101 - accuracy: 0.1061
# Epoch 6/30
# 60000/60000 [==============================] - 6s 102us/sample - loss: 27.6101 - accuracy: 0.1069
# Epoch 7/30
# 60000/60000 [==============================] - 7s 120us/sample - loss: 27.6101 - accuracy: 0.1078
# Epoch 8/30
# 60000/60000 [==============================] - 6s 95us/sample - loss: 27.6101 - accuracy: 0.1080
# Epoch 9/30
# 60000/60000 [==============================] - 6s 94us/sample - loss: 27.6101 - accuracy: 0.1082
# Epoch 10/30
# 60000/60000 [==============================] - 8s 136us/sample - loss: 27.6101 - accuracy: 0.1084
# Epoch 11/30
# 60000/60000 [==============================] - 9s 157us/sample - loss: 27.6101 - accuracy: 0.1089
# Epoch 12/30
# 60000/60000 [==============================] - 9s 142us/sample - loss: 27.6101 - accuracy: 0.1085
# Epoch 13/30
# 60000/60000 [==============================] - 7s 111us/sample - loss: 27.6100 - accuracy: 0.1091
# Epoch 14/30
# 60000/60000 [==============================] - 11s 188us/sample - loss: 27.6100 - accuracy: 0.1089
# Epoch 15/30
# 60000/60000 [==============================] - 8s 132us/sample - loss: 27.6100 - accuracy: 0.1088
# Epoch 16/30
# 60000/60000 [==============================] - 7s 110us/sample - loss: 27.6100 - accuracy: 0.1088
# Epoch 17/30
# 60000/60000 [==============================] - 9s 144us/sample - loss: 27.6100 - accuracy: 0.1083
# Epoch 18/30
# 60000/60000 [==============================] - 6s 96us/sample - loss: 27.6100 - accuracy: 0.1086
# Epoch 19/30
# 60000/60000 [==============================] - 8s 129us/sample - loss: 27.6100 - accuracy: 0.1086
# Epoch 20/30
# 60000/60000 [==============================] - 7s 111us/sample - loss: 27.6100 - accuracy: 0.1093
# Epoch 21/30
# 60000/60000 [==============================] - 7s 116us/sample - loss: 27.6100 - accuracy: 0.1085
# Epoch 22/30
# 60000/60000 [==============================] - 8s 132us/sample - loss: 27.6100 - accuracy: 0.1091
# Epoch 23/30
# 60000/60000 [==============================] - 7s 113us/sample - loss: 27.6100 - accuracy: 0.1086
# Epoch 24/30
# 60000/60000 [==============================] - 13s 210us/sample - loss: 27.6100 - accuracy: 0.1090
# Epoch 25/30
# 60000/60000 [==============================] - 10s 162us/sample - loss: 27.6100 - accuracy: 0.1081
# Epoch 26/30
# 60000/60000 [==============================] - 9s 152us/sample - loss: 27.6100 - accuracy: 0.1088
# Epoch 27/30
# 60000/60000 [==============================] - 8s 135us/sample - loss: 27.6100 - accuracy: 0.1083
# Epoch 28/30
# 60000/60000 [==============================] - 12s 195us/sample - loss: 27.6100 - accuracy: 0.1084
# Epoch 29/30
# 60000/60000 [==============================] - 9s 145us/sample - loss: 27.6100 - accuracy: 0.1086
# Epoch 30/30
# 60000/60000 [==============================] - 9s 145us/sample - loss: 27.6100 - accuracy: 0.1084
# [27.610037481689453, 0.1107]

# %% [markdown]
# ### Using Adam optimizer and sparse_categorical_crossentropy loss function

# %%
mnist = tf.keras.datasets.fashion_mnist
(training_images, training_labels) ,  (test_images, test_labels) = mnist.load_data()

training_images = training_images/1.0
test_images = test_images/1.0

model = tf.keras.models.Sequential([tf.keras.layers.Flatten(),
                                    tf.keras.layers.Dense(128, activation=tf.nn.relu),
                                    tf.keras.layers.Dense(10, activation=tf.nn.softmax)])

model.compile(optimizer = 'adam',
              loss = 'sparse_categorical_crossentropy',metrics=['accuracy'])

model.fit(training_images, training_labels, epochs=30)

model.evaluate(test_images, test_labels,verbose=0)
# Out:
# Train on 60000 samples
# Epoch 1/30
# 60000/60000 [==============================] - 3s 53us/sample - loss: 3.0271 - accuracy: 0.6788
# Epoch 2/30
# 60000/60000 [==============================] - 3s 50us/sample - loss: 0.6632 - accuracy: 0.7546
# Epoch 3/30
# 60000/60000 [==============================] - 3s 48us/sample - loss: 0.5574 - accuracy: 0.8018
# Epoch 4/30
# 60000/60000 [==============================] - 3s 48us/sample - loss: 0.5301 - accuracy: 0.8156
# Epoch 5/30
# 60000/60000 [==============================] - 3s 50us/sample - loss: 0.5028 - accuracy: 0.8267
# Epoch 6/30
# 60000/60000 [==============================] - 3s 51us/sample - loss: 0.4962 - accuracy: 0.8294
# Epoch 7/30
# 60000/60000 [==============================] - 3s 50us/sample - loss: 0.4853 - accuracy: 0.8361
# Epoch 8/30
# 60000/60000 [==============================] - 3s 49us/sample - loss: 0.4750 - accuracy: 0.8393
# Epoch 9/30
# 60000/60000 [==============================] - 3s 49us/sample - loss: 0.4756 - accuracy: 0.8401
# Epoch 10/30
# 60000/60000 [==============================] - 3s 49us/sample - loss: 0.4640 - accuracy: 0.8416
# Epoch 11/30
# 60000/60000 [==============================] - 3s 48us/sample - loss: 0.4708 - accuracy: 0.8410s - loss: 0.4727 - accuracy
# Epoch 12/30
# 60000/60000 [==============================] - 3s 50us/sample - loss: 0.4560 - accuracy: 0.8469
# Epoch 13/30
# 60000/60000 [==============================] - 6s 94us/sample - loss: 0.4576 - accuracy: 0.8457
# Epoch 14/30
# 60000/60000 [==============================] - 4s 71us/sample - loss: 0.4514 - accuracy: 0.8467
# Epoch 15/30
# 60000/60000 [==============================] - 9s 156us/sample - loss: 0.4533 - accuracy: 0.8481
# Epoch 16/30
# 60000/60000 [==============================] - 6s 102us/sample - loss: 0.4470 - accuracy: 0.8492
# Epoch 17/30
# 60000/60000 [==============================] - 4s 70us/sample - loss: 0.4511 - accuracy: 0.8485
# Epoch 18/30
# 60000/60000 [==============================] - 5s 77us/sample - loss: 0.4422 - accuracy: 0.8508
# Epoch 19/30
# 60000/60000 [==============================] - 5s 76us/sample - loss: 0.4558 - accuracy: 0.8490
# Epoch 20/30
# 60000/60000 [==============================] - 4s 72us/sample - loss: 0.4496 - accuracy: 0.8498
# Epoch 21/30
# 60000/60000 [==============================] - 6s 100us/sample - loss: 0.4378 - accuracy: 0.8555
# Epoch 22/30
# 60000/60000 [==============================] - 8s 128us/sample - loss: 0.4426 - accuracy: 0.8523
# Epoch 23/30
# 60000/60000 [==============================] - 9s 153us/sample - loss: 0.4398 - accuracy: 0.8546
# Epoch 24/30
# 60000/60000 [==============================] - 7s 123us/sample - loss: 0.4390 - accuracy: 0.8541
# Epoch 25/30
# 60000/60000 [==============================] - 5s 78us/sample - loss: 0.4457 - accuracy: 0.8516
# Epoch 26/30
# 60000/60000 [==============================] - 5s 76us/sample - loss: 0.4327 - accuracy: 0.8558
# Epoch 27/30
# 60000/60000 [==============================] - 5s 90us/sample - loss: 0.4456 - accuracy: 0.8536
# Epoch 28/30
# 60000/60000 [==============================] - 5s 77us/sample - loss: 0.4421 - accuracy: 0.8553
# Epoch 29/30
# 60000/60000 [==============================] - 9s 142us/sample - loss: 0.4278 - accuracy: 0.8569
# Epoch 30/30
# 60000/60000 [==============================] - 5s 90us/sample - loss: 0.4444 - accuracy: 0.8557
# [0.6281270745754242, 0.8133]

# %% [markdown]
# ### Model 3 : With Normalization

# %%
mnist = tf.keras.datasets.fashion_mnist
(training_images, training_labels) ,  (test_images, test_labels) = mnist.load_data()

training_images = training_images/255.0
test_images = test_images/255.0

model = tf.keras.models.Sequential([tf.keras.layers.Flatten(),
                                    tf.keras.layers.Dense(128, activation=tf.nn.relu),
                                    tf.keras.layers.Dense(10, activation=tf.nn.softmax)])

model.compile(optimizer = 'adam',
              loss = 'sparse_categorical_crossentropy',metrics=['accuracy'])

model.fit(training_images, training_labels, epochs=30)

model.evaluate(test_images, test_labels,verbose=0)
# Out:
# Train on 60000 samples
# Epoch 1/30
# 60000/60000 [==============================] - 7s 114us/sample - loss: 0.5021 - accuracy: 0.8242
# Epoch 2/30
# 60000/60000 [==============================] - 4s 69us/sample - loss: 0.3765 - accuracy: 0.8645
# Epoch 3/30
# 60000/60000 [==============================] - 5s 88us/sample - loss: 0.3342 - accuracy: 0.8774
# Epoch 4/30
# 60000/60000 [==============================] - 4s 74us/sample - loss: 0.3115 - accuracy: 0.8860
# Epoch 5/30
# 60000/60000 [==============================] - 6s 107us/sample - loss: 0.2952 - accuracy: 0.8908
# Epoch 6/30
# 60000/60000 [==============================] - 4s 73us/sample - loss: 0.2796 - accuracy: 0.8962
# Epoch 7/30
# 60000/60000 [==============================] - 4s 72us/sample - loss: 0.2683 - accuracy: 0.8995
# Epoch 8/30
# 60000/60000 [==============================] - 5s 83us/sample - loss: 0.2567 - accuracy: 0.9049
# Epoch 9/30
# 60000/60000 [==============================] - 6s 101us/sample - loss: 0.2461 - accuracy: 0.9077
# Epoch 10/30
# 60000/60000 [==============================] - 5s 80us/sample - loss: 0.2371 - accuracy: 0.9113
# Epoch 11/30
# 60000/60000 [==============================] - 5s 75us/sample - loss: 0.2296 - accuracy: 0.9128
# Epoch 12/30
# 60000/60000 [==============================] - 4s 73us/sample - loss: 0.2230 - accuracy: 0.9175
# Epoch 13/30
# 60000/60000 [==============================] - 5s 78us/sample - loss: 0.2162 - accuracy: 0.9188
# Epoch 14/30
# 60000/60000 [==============================] - 5s 87us/sample - loss: 0.2098 - accuracy: 0.9214
# Epoch 15/30
# 60000/60000 [==============================] - 6s 102us/sample - loss: 0.2039 - accuracy: 0.9231
# Epoch 16/30
# 60000/60000 [==============================] - 6s 108us/sample - loss: 0.1962 - accuracy: 0.9266
# Epoch 17/30
# 60000/60000 [==============================] - 4s 74us/sample - loss: 0.1920 - accuracy: 0.9284
# Epoch 18/30
# 60000/60000 [==============================] - 5s 83us/sample - loss: 0.1866 - accuracy: 0.9308
# Epoch 19/30
# 60000/60000 [==============================] - ETA: 0s - loss: 0.1821 - accuracy: 0.93 - 5s 80us/sample - loss: 0.1823 - accuracy: 0.9313
# Epoch 20/30
# 60000/60000 [==============================] - 5s 85us/sample - loss: 0.1770 - accuracy: 0.9341
# Epoch 21/30
# 60000/60000 [==============================] - 6s 93us/sample - loss: 0.1731 - accuracy: 0.9358
# Epoch 22/30
# 60000/60000 [==============================] - 5s 76us/sample - loss: 0.1720 - accuracy: 0.9353
# Epoch 23/30
# 60000/60000 [==============================] - 4s 68us/sample - loss: 0.1658 - accuracy: 0.9374
# Epoch 24/30
# 60000/60000 [==============================] - 4s 69us/sample - loss: 0.1619 - accuracy: 0.9392
# Epoch 25/30
# 60000/60000 [==============================] - 4s 69us/sample - loss: 0.1574 - accuracy: 0.9410
# Epoch 26/30
# 60000/60000 [==============================] - 4s 73us/sample - loss: 0.1550 - accuracy: 0.9418
# Epoch 27/30
# 60000/60000 [==============================] - 4s 69us/sample - loss: 0.1506 - accuracy: 0.9442
# Epoch 28/30
# 60000/60000 [==============================] - 5s 83us/sample - loss: 0.1476 - accuracy: 0.9457
# Epoch 29/30
# 60000/60000 [==============================] - 4s 75us/sample - loss: 0.1441 - accuracy: 0.9461
# Epoch 30/30
# 60000/60000 [==============================] - 5s 80us/sample - loss: 0.1386 - accuracy: 0.9477
# [0.40890381172299384, 0.8853]

# %% [markdown]
# ### Model 4 : with 512 neurons

# %%
mnist = tf.keras.datasets.fashion_mnist
(training_images, training_labels) ,  (test_images, test_labels) = mnist.load_data()

training_images = training_images/255.0
test_images = test_images/255.0

model = tf.keras.models.Sequential([tf.keras.layers.Flatten(),
                                    tf.keras.layers.Dense(512, activation=tf.nn.relu),
                                    tf.keras.layers.Dense(10, activation=tf.nn.softmax)])

model.compile(optimizer = 'adam',
              loss = 'sparse_categorical_crossentropy',metrics=['accuracy'])

model.fit(training_images, training_labels, epochs=50)

model.evaluate(test_images, test_labels,verbose=0)
# Out:
# Train on 60000 samples
# Epoch 1/50
# 60000/60000 [==============================] - 3s 46us/sample - loss: 0.4746 - accuracy: 0.8314
# Epoch 2/50
# 60000/60000 [==============================] - 3s 43us/sample - loss: 0.3592 - accuracy: 0.8689s - loss: 0.3 - ETA: 0s - loss:
# Epoch 3/50
# 60000/60000 [==============================] - 3s 43us/sample - loss: 0.3208 - accuracy: 0.8826
# Epoch 4/50
# 60000/60000 [==============================] - 3s 43us/sample - loss: 0.2982 - accuracy: 0.8904
# Epoch 5/50
# 60000/60000 [==============================] - 3s 43us/sample - loss: 0.2789 - accuracy: 0.8968
# Epoch 6/50
# 60000/60000 [==============================] - 3s 43us/sample - loss: 0.2640 - accuracy: 0.9011
# Epoch 7/50
# 60000/60000 [==============================] - 3s 43us/sample - loss: 0.2518 - accuracy: 0.9062
# Epoch 8/50
# 60000/60000 [==============================] - 3s 43us/sample - loss: 0.2398 - accuracy: 0.9096
# Epoch 9/50
# 60000/60000 [==============================] - 3s 43us/sample - loss: 0.2311 - accuracy: 0.9132
# Epoch 10/50
# 60000/60000 [==============================] - 3s 43us/sample - loss: 0.2192 - accuracy: 0.9172
# Epoch 11/50
# 60000/60000 [==============================] - 3s 43us/sample - loss: 0.2137 - accuracy: 0.9186
# Epoch 12/50
# 60000/60000 [==============================] - 3s 44us/sample - loss: 0.2059 - accuracy: 0.9230s - loss: 0.2058 - accuracy: 0.92
# Epoch 13/50
# 60000/60000 [==============================] - 3s 44us/sample - loss: 0.1971 - accuracy: 0.9258
# Epoch 14/50
# 60000/60000 [==============================] - 3s 44us/sample - loss: 0.1926 - accuracy: 0.9272
# Epoch 15/50
# 60000/60000 [==============================] - 3s 44us/sample - loss: 0.1859 - accuracy: 0.9297
# Epoch 16/50
# 60000/60000 [==============================] - 3s 45us/sample - loss: 0.1791 - accuracy: 0.9328
# Epoch 17/50
# 60000/60000 [==============================] - 3s 44us/sample - loss: 0.1743 - accuracy: 0.9348
# Epoch 18/50
# 60000/60000 [==============================] - 3s 44us/sample - loss: 0.1678 - accuracy: 0.9368
# Epoch 19/50
# 60000/60000 [==============================] - 3s 45us/sample - loss: 0.1612 - accuracy: 0.9401
# Epoch 20/50
# 60000/60000 [==============================] - 3s 44us/sample - loss: 0.1566 - accuracy: 0.9414
# Epoch 21/50
# 60000/60000 [==============================] - 3s 45us/sample - loss: 0.1530 - accuracy: 0.9415s - loss:
# Epoch 22/50
# 60000/60000 [==============================] - 3s 44us/sample - loss: 0.1488 - accuracy: 0.9431
# Epoch 23/50
# 60000/60000 [==============================] - 3s 45us/sample - loss: 0.1453 - accuracy: 0.9452
# Epoch 24/50
# 60000/60000 [==============================] - 3s 46us/sample - loss: 0.1414 - accuracy: 0.9465
# Epoch 25/50
# 60000/60000 [==============================] - 3s 46us/sample - loss: 0.1373 - accuracy: 0.9478
# Epoch 26/50
# 60000/60000 [==============================] - 4s 59us/sample - loss: 0.1332 - accuracy: 0.9500
# Epoch 27/50
# 60000/60000 [==============================] - 3s 46us/sample - loss: 0.1302 - accuracy: 0.9501
# Epoch 28/50
# 60000/60000 [==============================] - 3s 45us/sample - loss: 0.1262 - accuracy: 0.9528
# Epoch 29/50
# 60000/60000 [==============================] - 3s 46us/sample - loss: 0.1214 - accuracy: 0.9544
# Epoch 30/50
# 60000/60000 [==============================] - 3s 55us/sample - loss: 0.1209 - accuracy: 0.9546
# Epoch 31/50
# 60000/60000 [==============================] - 3s 46us/sample - loss: 0.1154 - accuracy: 0.9566
# Epoch 32/50
# 60000/60000 [==============================] - 3s 46us/sample - loss: 0.1156 - accuracy: 0.9570
# Epoch 33/50
# 60000/60000 [==============================] - 3s 48us/sample - loss: 0.1112 - accuracy: 0.9583
# Epoch 34/50
# 60000/60000 [==============================] - 3s 56us/sample - loss: 0.1096 - accuracy: 0.9583s
# Epoch 35/50
# 60000/60000 [==============================] - 3s 55us/sample - loss: 0.1072 - accuracy: 0.9597
# Epoch 36/50
# 60000/60000 [==============================] - 3s 56us/sample - loss: 0.1064 - accuracy: 0.9597
# Epoch 37/50
# 60000/60000 [==============================] - 3s 57us/sample - loss: 0.1000 - accuracy: 0.9619
# Epoch 38/50
# 60000/60000 [==============================] - 3s 55us/sample - loss: 0.0985 - accuracy: 0.9641
# Epoch 39/50
# 60000/60000 [==============================] - 3s 56us/sample - loss: 0.1000 - accuracy: 0.9632s
# Epoch 40/50
# 60000/60000 [==============================] - 3s 57us/sample - loss: 0.0971 - accuracy: 0.9641s - loss: 0.0972 - accuracy:
# Epoch 41/50
# 60000/60000 [==============================] - 3s 56us/sample - loss: 0.0911 - accuracy: 0.9653
# Epoch 42/50
# 60000/60000 [==============================] - 3s 57us/sample - loss: 0.0943 - accuracy: 0.9642
# Epoch 43/50
# 60000/60000 [==============================] - 3s 57us/sample - loss: 0.0904 - accuracy: 0.9658
# Epoch 44/50
# 60000/60000 [==============================] - 3s 57us/sample - loss: 0.0906 - accuracy: 0.9657
# Epoch 45/50
# 60000/60000 [==============================] - 3s 57us/sample - loss: 0.0855 - accuracy: 0.9683
# Epoch 46/50
# 60000/60000 [==============================] - 3s 58us/sample - loss: 0.0838 - accuracy: 0.9684
# Epoch 47/50
# 60000/60000 [==============================] - 3s 57us/sample - loss: 0.0836 - accuracy: 0.9692
# Epoch 48/50
# 60000/60000 [==============================] - 4s 58us/sample - loss: 0.0838 - accuracy: 0.9682
# Epoch 49/50
# 60000/60000 [==============================] - 4s 59us/sample - loss: 0.0822 - accuracy: 0.9697
# Epoch 50/50
# 60000/60000 [==============================] - 4s 59us/sample - loss: 0.0804 - accuracy: 0.9706
# [0.5686816045455635, 0.8923]

# %% [markdown]
# ### Model 5: with 1024 neurons

# %%
mnist = tf.keras.datasets.fashion_mnist
(training_images, training_labels) ,  (test_images, test_labels) = mnist.load_data()

training_images = training_images/255.0
test_images = test_images/255.0

model = tf.keras.models.Sequential([tf.keras.layers.Flatten(),
                                    tf.keras.layers.Dense(1024, activation=tf.nn.relu),
                                    tf.keras.layers.Dense(10, activation=tf.nn.softmax)])

model.compile(optimizer = 'adam',
              loss = 'sparse_categorical_crossentropy',metrics=['accuracy'])

model.fit(training_images, training_labels, epochs=30)

model.evaluate(test_images, test_labels,verbose=0)
# Out:
# Train on 60000 samples
# Epoch 1/30
# 60000/60000 [==============================] - 11s 191us/sample - loss: 0.4674 - accuracy: 0.8325
# Epoch 2/30
# 60000/60000 [==============================] - 11s 178us/sample - loss: 0.3545 - accuracy: 0.8699
# Epoch 3/30
# 60000/60000 [==============================] - 11s 188us/sample - loss: 0.3216 - accuracy: 0.8814
# Epoch 4/30
# 60000/60000 [==============================] - 11s 183us/sample - loss: 0.2949 - accuracy: 0.8902
# Epoch 5/30
# 60000/60000 [==============================] - 11s 176us/sample - loss: 0.2784 - accuracy: 0.8967
# Epoch 6/30
# 60000/60000 [==============================] - 11s 175us/sample - loss: 0.2654 - accuracy: 0.9003
# Epoch 7/30
# 60000/60000 [==============================] - 11s 190us/sample - loss: 0.2519 - accuracy: 0.9062
# Epoch 8/30
# 60000/60000 [==============================] - 10s 170us/sample - loss: 0.2407 - accuracy: 0.9098
# Epoch 9/30
# 60000/60000 [==============================] - 11s 188us/sample - loss: 0.2289 - accuracy: 0.9140
# Epoch 10/30
# 60000/60000 [==============================] - 9s 147us/sample - loss: 0.2226 - accuracy: 0.9162
# Epoch 11/30
# 60000/60000 [==============================] - 9s 142us/sample - loss: 0.2117 - accuracy: 0.9208
# Epoch 12/30
# 60000/60000 [==============================] - 11s 190us/sample - loss: 0.2047 - accuracy: 0.9224
# Epoch 13/30
# 60000/60000 [==============================] - 10s 165us/sample - loss: 0.1961 - accuracy: 0.9259
# Epoch 14/30
# 60000/60000 [==============================] - 10s 162us/sample - loss: 0.1916 - accuracy: 0.9281
# Epoch 15/30
# 60000/60000 [==============================] - 13s 220us/sample - loss: 0.1847 - accuracy: 0.9296
# Epoch 16/30
# 60000/60000 [==============================] - 12s 197us/sample - loss: 0.1781 - accuracy: 0.9316
# Epoch 17/30
# 60000/60000 [==============================] - 12s 208us/sample - loss: 0.1715 - accuracy: 0.9348
# Epoch 18/30
# 60000/60000 [==============================] - 12s 203us/sample - loss: 0.1665 - accuracy: 0.9365
# Epoch 19/30
# 60000/60000 [==============================] - 12s 205us/sample - loss: 0.1636 - accuracy: 0.9385
# Epoch 20/30
# 60000/60000 [==============================] - 10s 165us/sample - loss: 0.1567 - accuracy: 0.9400
# Epoch 21/30
# 60000/60000 [==============================] - 11s 180us/sample - loss: 0.1524 - accuracy: 0.9426
# Epoch 22/30
# 60000/60000 [==============================] - 12s 193us/sample - loss: 0.1478 - accuracy: 0.9441
# Epoch 23/30
# 60000/60000 [==============================] - 10s 172us/sample - loss: 0.1454 - accuracy: 0.9457
# Epoch 24/30
# 60000/60000 [==============================] - 13s 211us/sample - loss: 0.1393 - accuracy: 0.9467
# Epoch 25/30
# 60000/60000 [==============================] - 11s 186us/sample - loss: 0.1362 - accuracy: 0.9488
# Epoch 26/30
# 60000/60000 [==============================] - 11s 180us/sample - loss: 0.1326 - accuracy: 0.9497
# Epoch 27/30
# 60000/60000 [==============================] - 11s 182us/sample - loss: 0.1319 - accuracy: 0.9503
# Epoch 28/30
# 60000/60000 [==============================] - 10s 173us/sample - loss: 0.1262 - accuracy: 0.9525
# Epoch 29/30
# 60000/60000 [==============================] - 10s 174us/sample - loss: 0.1246 - accuracy: 0.9528
# Epoch 30/30
# 60000/60000 [==============================] - 10s 169us/sample - loss: 0.1211 - accuracy: 0.9549
# [0.45793095045685767, 0.8906]

# %% [markdown]
# ### Model 6: with 2 hidden layers

# %%
mnist = tf.keras.datasets.fashion_mnist
(training_images, training_labels) ,  (test_images, test_labels) = mnist.load_data()

training_images = training_images/255.0
test_images = test_images/255.0

model = tf.keras.models.Sequential([tf.keras.layers.Flatten(),
                                    tf.keras.layers.Dense(128, activation=tf.nn.relu),
                                    tf.keras.layers.Dense(256, activation=tf.nn.relu),
                                    tf.keras.layers.Dense(10, activation=tf.nn.softmax)])

model.compile(optimizer = 'adam',
              loss = 'sparse_categorical_crossentropy',metrics=['accuracy'])

model.fit(training_images, training_labels, epochs=30)

model.evaluate(test_images, test_labels,verbose=0)
# Out:
# Train on 60000 samples
# Epoch 1/30
# 60000/60000 [==============================] - 6s 93us/sample - loss: 0.4851 - accuracy: 0.8252
# Epoch 2/30
# 60000/60000 [==============================] - 6s 106us/sample - loss: 0.3605 - accuracy: 0.8675
# Epoch 3/30
# 60000/60000 [==============================] - 4s 74us/sample - loss: 0.3272 - accuracy: 0.8785
# Epoch 4/30
# 60000/60000 [==============================] - 6s 101us/sample - loss: 0.3042 - accuracy: 0.8872
# Epoch 5/30
# 60000/60000 [==============================] - 5s 80us/sample - loss: 0.2857 - accuracy: 0.8937
# Epoch 6/30
# 60000/60000 [==============================] - 5s 78us/sample - loss: 0.2712 - accuracy: 0.8984
# Epoch 7/30
# 60000/60000 [==============================] - 4s 72us/sample - loss: 0.2578 - accuracy: 0.9043
# Epoch 8/30
# 60000/60000 [==============================] - 5s 77us/sample - loss: 0.2464 - accuracy: 0.9070
# Epoch 9/30
# 60000/60000 [==============================] - 7s 120us/sample - loss: 0.2384 - accuracy: 0.9093
# Epoch 10/30
# 60000/60000 [==============================] - 5s 82us/sample - loss: 0.2270 - accuracy: 0.9141
# Epoch 11/30
# 60000/60000 [==============================] - 4s 73us/sample - loss: 0.2207 - accuracy: 0.9165
# Epoch 12/30
# 60000/60000 [==============================] - 4s 71us/sample - loss: 0.2103 - accuracy: 0.9202
# Epoch 13/30
# 60000/60000 [==============================] - 5s 80us/sample - loss: 0.2028 - accuracy: 0.9225
# Epoch 14/30
# 60000/60000 [==============================] - 4s 70us/sample - loss: 0.1965 - accuracy: 0.9253
# Epoch 15/30
# 60000/60000 [==============================] - 5s 77us/sample - loss: 0.1874 - accuracy: 0.9279
# Epoch 16/30
# 60000/60000 [==============================] - 4s 71us/sample - loss: 0.1838 - accuracy: 0.9288
# Epoch 17/30
# 60000/60000 [==============================] - 5s 75us/sample - loss: 0.1776 - accuracy: 0.9319
# Epoch 18/30
# 60000/60000 [==============================] - 5s 75us/sample - loss: 0.1735 - accuracy: 0.9341
# Epoch 19/30
# 60000/60000 [==============================] - 5s 83us/sample - loss: 0.1658 - accuracy: 0.9367
# Epoch 20/30
# 60000/60000 [==============================] - 5s 87us/sample - loss: 0.1622 - accuracy: 0.9380
# Epoch 21/30
# 60000/60000 [==============================] - 5s 77us/sample - loss: 0.1581 - accuracy: 0.9403
# Epoch 22/30
# 60000/60000 [==============================] - 6s 100us/sample - loss: 0.1533 - accuracy: 0.9414
# Epoch 23/30
# 60000/60000 [==============================] - 6s 93us/sample - loss: 0.1497 - accuracy: 0.9423
# Epoch 24/30
# 60000/60000 [==============================] - 6s 106us/sample - loss: 0.1471 - accuracy: 0.9430
# Epoch 25/30
# 60000/60000 [==============================] - 5s 86us/sample - loss: 0.1399 - accuracy: 0.9464
# Epoch 26/30
# 60000/60000 [==============================] - 5s 79us/sample - loss: 0.1364 - accuracy: 0.9479
# Epoch 27/30
# 60000/60000 [==============================] - 5s 79us/sample - loss: 0.1352 - accuracy: 0.9484
# Epoch 28/30
# 60000/60000 [==============================] - 8s 134us/sample - loss: 0.1282 - accuracy: 0.9508
# Epoch 29/30
# 60000/60000 [==============================] - 5s 80us/sample - loss: 0.1273 - accuracy: 0.9511
# Epoch 30/30
# 60000/60000 [==============================] - ETA: 0s - loss: 0.1249 - accuracy: 0.95 - 6s 93us/sample - loss: 0.1251 - accuracy: 0.9516
# [0.4613285664200783, 0.8861]

# %% [markdown]
# ### Remark: In model 4 and model 5, we can see our loss is increasing in middle, there is no point in training the model if your loss is increasing. It is better to stop if your loss hits a specific value.

# %% [markdown]
# ### Model 7 : Using Callbacks on model 4, since it performed better of all

# %%
class myCallback(tf.keras.callbacks.Callback):
  def on_epoch_end(self, epoch, logs={}):
    print(logs)
    if(logs.get('accuracy')>0.95):
      print("\nReached 95% accuracy so cancelling training!")
      self.model.stop_training = True

callbacks = myCallback()

# %%
mnist = tf.keras.datasets.fashion_mnist
(training_images, training_labels), (test_images, test_labels) = mnist.load_data()
training_images=training_images/255.0
test_images=test_images/255.0
model = tf.keras.models.Sequential([
  tf.keras.layers.Flatten(),
  tf.keras.layers.Dense(512, activation=tf.nn.relu),
  tf.keras.layers.Dense(10, activation=tf.nn.softmax)
])
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy',metrics=['accuracy'])
model.fit(training_images, training_labels, epochs=30, callbacks=[callbacks])
# Out:
# Train on 60000 samples
# Epoch 1/30
# 59840/60000 [============================>.] - ETA: 0s - loss: 0.4749 - accuracy: 0.8293{'loss': 0.47501132513284683, 'accuracy': 0.82923335}
# 60000/60000 [==============================] - 11s 188us/sample - loss: 0.4750 - accuracy: 0.8292
# Epoch 2/30
# 59712/60000 [============================>.] - ETA: 0s - loss: 0.3577 - accuracy: 0.8693{'loss': 0.3575009008526802, 'accuracy': 0.86938334}
# 60000/60000 [==============================] - 10s 163us/sample - loss: 0.3575 - accuracy: 0.8694
# Epoch 3/30
# 59904/60000 [============================>.] - ETA: 0s - loss: 0.3228 - accuracy: 0.8807{'loss': 0.32264195246100424, 'accuracy': 0.8807}
# 60000/60000 [==============================] - 10s 159us/sample - loss: 0.3226 - accuracy: 0.8807
# Epoch 4/30
# 59776/60000 [============================>.] - ETA: 0s - loss: 0.2981 - accuracy: 0.8897{'loss': 0.29825760840972265, 'accuracy': 0.8896667}
# 60000/60000 [==============================] - 10s 161us/sample - loss: 0.2983 - accuracy: 0.8897
# Epoch 5/30
# 59904/60000 [============================>.] - ETA: 0s - loss: 0.2794 - accuracy: 0.8952{'loss': 0.27933113978703816, 'accuracy': 0.89521664}
# 60000/60000 [==============================] - 10s 161us/sample - loss: 0.2793 - accuracy: 0.8952
# Epoch 6/30
# 59744/60000 [============================>.] - ETA: 0s - loss: 0.2649 - accuracy: 0.9020{'loss': 0.264520653706789, 'accuracy': 0.90213335}
# 60000/60000 [==============================] - 10s 159us/sample - loss: 0.2645 - accuracy: 0.9021
# Epoch 7/30
# 59776/60000 [============================>.] - ETA: 0s - loss: 0.2524 - accuracy: 0.9056{'loss': 0.2525299337307612, 'accuracy': 0.9055333}
# 60000/60000 [==============================] - 10s 161us/sample - loss: 0.2525 - accuracy: 0.9055
# Epoch 8/30
# 59904/60000 [============================>.] - ETA: 0s - loss: 0.2408 - accuracy: 0.9095{'loss': 0.24075387221972147, 'accuracy': 0.9094667}
# 60000/60000 [==============================] - 11s 177us/sample - loss: 0.2408 - accuracy: 0.9095
# Epoch 9/30
# 59968/60000 [============================>.] - ETA: 0s - loss: 0.2309 - accuracy: 0.9130{'loss': 0.2308827175979813, 'accuracy': 0.91298336}
# 60000/60000 [==============================] - 9s 153us/sample - loss: 0.2309 - accuracy: 0.9130
# Epoch 10/30
# 59840/60000 [============================>.] - ETA: 0s - loss: 0.2221 - accuracy: 0.9166{'loss': 0.22234215939541657, 'accuracy': 0.91646665}
# 60000/60000 [==============================] - 10s 161us/sample - loss: 0.2223 - accuracy: 0.9165
# Epoch 11/30
# 59872/60000 [============================>.] - ETA: 0s - loss: 0.2150 - accuracy: 0.9183{'loss': 0.21495480539600054, 'accuracy': 0.9183}
# 60000/60000 [==============================] - 10s 160us/sample - loss: 0.2150 - accuracy: 0.9183
# Epoch 12/30
# 59776/60000 [============================>.] - ETA: 0s - loss: 0.2040 - accuracy: 0.9241{'loss': 0.20410253929297129, 'accuracy': 0.92406666}
# 60000/60000 [==============================] - 7s 119us/sample - loss: 0.2041 - accuracy: 0.9241
# Epoch 13/30
# 59968/60000 [============================>.] - ETA: 0s - loss: 0.1993 - accuracy: 0.9253{'loss': 0.19938736699124177, 'accuracy': 0.9252667}
# 60000/60000 [==============================] - 9s 151us/sample - loss: 0.1994 - accuracy: 0.9253
# Epoch 14/30
# 59712/60000 [============================>.] - ETA: 0s - loss: 0.1908 - accuracy: 0.9276{'loss': 0.1905601991261045, 'accuracy': 0.9277167}
# 60000/60000 [==============================] - 10s 170us/sample - loss: 0.1906 - accuracy: 0.9277
# Epoch 15/30
# 59872/60000 [============================>.] - ETA: 0s - loss: 0.1850 - accuracy: 0.9304 ETA: 1s - loss: 0{'loss': 0.18484127268195152, 'accuracy': 0.9304}
# 60000/60000 [==============================] - 7s 115us/sample - loss: 0.1848 - accuracy: 0.9304
# Epoch 16/30
# 58784/60000 [============================>.] - ETA: 0s - loss: 0.1781 - accuracy: 0.9332{'loss': 0.1783996996263663, 'accuracy': 0.93291664}
# 60000/60000 [==============================] - 3s 45us/sample - loss: 0.1784 - accuracy: 0.9329
# Epoch 17/30
# 59648/60000 [============================>.] - ETA: 0s - loss: 0.1737 - accuracy: 0.9338 ETA: 0s - l{'loss': 0.17394471575816473, 'accuracy': 0.93371665}
# 60000/60000 [==============================] - 3s 45us/sample - loss: 0.1739 - accuracy: 0.9337
# Epoch 18/30
# 59648/60000 [============================>.] - ETA: 0s - loss: 0.1704 - accuracy: 0.9352 ETA: 0s - loss: 0.1696 - ac{'loss': 0.17034830478802324, 'accuracy': 0.9353}
# 60000/60000 [==============================] - 3s 44us/sample - loss: 0.1703 - accuracy: 0.9353
# Epoch 19/30
# 59616/60000 [============================>.] - ETA: 0s - loss: 0.1611 - accuracy: 0.9397{'loss': 0.16123553393197557, 'accuracy': 0.9397333}
# 60000/60000 [==============================] - 3s 44us/sample - loss: 0.1612 - accuracy: 0.9397
# Epoch 20/30
# 59520/60000 [============================>.] - ETA: 0s - loss: 0.1568 - accuracy: 0.9407{'loss': 0.1570300401188433, 'accuracy': 0.9406667}
# 60000/60000 [==============================] - 3s 44us/sample - loss: 0.1570 - accuracy: 0.9407
# Epoch 21/30
# 59488/60000 [============================>.] - ETA: 0s - loss: 0.1530 - accuracy: 0.9420{'loss': 0.15310854314963024, 'accuracy': 0.94203335}
# 60000/60000 [==============================] - 3s 52us/sample - loss: 0.1531 - accuracy: 0.9420
# Epoch 22/30
# 59552/60000 [============================>.] - ETA: 0s - loss: 0.1492 - accuracy: 0.9438 ETA: 0s - loss: 0.1488 - accu{'loss': 0.14905349958936373, 'accuracy': 0.94383335}
# 60000/60000 [==============================] - 3s 58us/sample - loss: 0.1491 - accuracy: 0.9438
# Epoch 23/30
# 59168/60000 [============================>.] - ETA: 0s - loss: 0.1443 - accuracy: 0.9454{'loss': 0.14430173955957096, 'accuracy': 0.94553334}
# 60000/60000 [==============================] - 4s 59us/sample - loss: 0.1443 - accuracy: 0.9455
# Epoch 24/30
# 58944/60000 [============================>.] - ETA: 0s - loss: 0.1419 - accuracy: 0.9468{'loss': 0.14261841049840052, 'accuracy': 0.9465167}
# 60000/60000 [==============================] - 3s 46us/sample - loss: 0.1426 - accuracy: 0.9465
# Epoch 25/30
# 59840/60000 [============================>.] - ETA: 0s - loss: 0.1366 - accuracy: 0.9483{'loss': 0.13682734150364995, 'accuracy': 0.9482333}
# 60000/60000 [==============================] - 3s 49us/sample - loss: 0.1368 - accuracy: 0.9482
# Epoch 26/30
# 59968/60000 [============================>.] - ETA: 0s - loss: 0.1326 - accuracy: 0.9493{'loss': 0.13258402677799264, 'accuracy': 0.9493333}
# 60000/60000 [==============================] - 3s 51us/sample - loss: 0.1326 - accuracy: 0.9493
# Epoch 27/30
# 59040/60000 [============================>.] - ETA: 0s - loss: 0.1290 - accuracy: 0.9518{'loss': 0.12901119422552487, 'accuracy': 0.95185}
#
# Reached 95% accuracy so cancelling training!
# 60000/60000 [==============================] - 3s 49us/sample - loss: 0.1290 - accuracy: 0.9518
